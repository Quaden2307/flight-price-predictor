# %%
import matplotlib.pyplot as plt
import pandas as pd

import sys
sys.path.append("..")

# %load_ext autoreload
# %autoreload 2

from src.data_init import load_data
from src.clean import clean_data

df = load_data()
df = clean_data(df)

df['fare'].hist()


df.plot(x='nsmiles', y='fare', kind='scatter')

df.plot(x='large_ms', y='fare', kind='scatter')

df.plot(x='nsmiles', y='large_ms', kind='scatter')

grouped = df.groupby("quarter")
nsmiles_by_quarter = grouped["nsmiles"]
avg_nsmiles = nsmiles_by_quarter.mean()
avg_nsmiles.plot(kind = "bar")
print(avg_nsmiles)

df.plot(x='nsmiles', y='fare_lg', kind='scatter')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# quarter
# 1    1073.609500
# 2    1064.725137
# 3    1060.636000
# 4    1064.514970
# Name: nsmiles, dtype: float64
# <Axes: xlabel='nsmiles', ylabel='fare_lg'>
