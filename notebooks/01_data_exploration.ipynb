# %%
import sys
sys.path.append("..")

import importlib
import src.data_init
import src.clean

importlib.reload(src.data_init)
importlib.reload(src.clean)

from src.data_init import load_data
from src.clean import clean_data

df = load_data()
df = clean_data(df)

df.head()
# Out:
#    Year  quarter  citymarketid_1  citymarketid_2  \
# 0  2025        3           32575           32457
# 1  2025        3           32467           31703
# 2  2025        3           32575           31703
# 3  2025        3           31703           31454
# 4  2025        3           30977           31703
#
#                                    city1  \
# 0    Los Angeles, CA (Metropolitan Area)
# 1          Miami, FL (Metropolitan Area)
# 2    Los Angeles, CA (Metropolitan Area)
# 3  New York City, NY (Metropolitan Area)
# 4                            Chicago, IL
#
#                                    city2  nsmiles  passengers    fare  \
# 0  San Francisco, CA (Metropolitan Area)      379       16376  161.24
# 1  New York City, NY (Metropolitan Area)     1118       14923  179.32
# 2  New York City, NY (Metropolitan Area)     2510       12437  404.00
# 3                            Orlando, FL      989       12411  161.94
# 4  New York City, NY (Metropolitan Area)      773       11243  210.80
#
#   carrier_lg  large_ms  fare_lg carrier_low   lf_ms  fare_low
# 0         WN    0.5038   168.32          AS  0.1076    154.31
# 1         DL    0.2510   200.50          NK  0.1165    106.95
# 2         UA    0.2579   396.43          B6  0.2492    317.93
# 3         B6    0.3558   160.50          NK  0.1288    101.83
# 4         UA    0.4616   220.24          AA  0.2500    203.30
