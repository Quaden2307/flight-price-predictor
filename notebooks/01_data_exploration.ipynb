# %%
import sys
sys.path.append("..")

import importlib
import src.data_init
import src.clean

importlib.reload(src.data_init)
importlib.reload(src.clean)

from src.data_init import load_data
from src.clean import clean_data

df = load_data()
df = clean_data(df)

df.tail()
# Out:
#       Year  quarter  citymarketid_1  citymarketid_2  \
# 6998  2024        1           31057           31136
# 6999  2024        1           32467           34685
# 7000  2024        1           33105           34100
# 7001  2023        4           32467           31703
# 7002  2023        4           32575           32457
#
#                                     city1  \
# 6998                        Charlotte, NC
# 6999        Miami, FL (Metropolitan Area)
# 7000                       Cincinnati, OH
# 7001        Miami, FL (Metropolitan Area)
# 7002  Los Angeles, CA (Metropolitan Area)
#
#                                       city2  nsmiles  passengers    fare  \
# 6998                       Jacksonville, FL      328         197  274.20
# 6999                           Savannah, GA      440         197  226.85
# 7000                       Philadelphia, PA      507         197  308.12
# 7001  New York City, NY (Metropolitan Area)     1118       18379  207.08
# ...
